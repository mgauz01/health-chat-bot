# %% [markdown]
# # Neural Network Chatbot

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from tensorflow.keras import layers
from tensorflow import keras
import random
from keras import Sequential
import tensorflow as tf
import torch
from torch import nn
import matplotlib.pyplot as plt

# %% [markdown]
# Let's make a dictionary out of the JSON file so that we can iterate over it so that there is read in datat that our models can use.

# %%
words = []
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# The next thing that will need to happen is that the

# %%
import nltk
nltk.download('punkt')

for intent in intents['intents']:
    for pattern in intent['patterns']:
        # Tokenize each word
        w = nltk.word_tokenize(pattern)
        # Put the tokenized version in the bigger words list
        words.extend(w)
        # Add documents in the corpus
        documents.append((w, intent['tag']))
        # Add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# [nltk_data] Downloading package punkt to /home/michael/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# lemmaztize and lower each word and remove duplicates
words = sorted(list(set([lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words])))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents", end='\n'*2)
# classes = intents
print (len(classes), "classes", classes, end='\n'*2)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words, end='\n'*2)
# Out:
# 282 documents
#
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
#
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# Let's dump the words and classes into pickle files
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# %%
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-25-9ffac2c3f218>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %%
from tensorflow.keras.optimizers import Adam

# %%
class NLP_Chatbot_Model(nn.Module):
    
    def __init__(self, y_size):
        super(NLP_Chatbot_Model, self).__init__()
        self.layers = nn.Sequential(
              nn.Linear(128, 64),      
              nn.Dropout(p=0.5),
              nn.ReLU(inplace=True),
              nn.Linear(64, 32),
              nn.Dropout(p=0.5),
              nn.ReLU(inplace=True),
              nn.Linear(32, y_size),
              nn.Dropout(p=0.5),
              nn.ReLU(inplace=True),
              nn.Linear(10, y_size))
        
        optimizer = torch.optim.Adam(self.parameters(), lr=0.0001, eps=1e-6)
        
    def forward(self, x):
        '''Trains the model in 
        accordance with the input `x`
        '''
        return self.layers(x)
        
    
    def predict(self, x):
        '''Return a prediction
        based off of an input `x`
        '''
        return self.forward(x)

# %%
#fitting and saving the model 
history = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', history)
print("The Model Has Been Trained")

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(layers.Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
opt = Adam(lr=0.0001, epsilon=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

#fitting and saving the model 
history = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', history)
print("The Model Has Been Trained")
# Out:
# /home/michael/.local/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 57/57 [==============================] - 1s 2ms/step - loss: 2.2266 - accuracy: 0.1064
# Epoch 2/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.1992 - accuracy: 0.1312
# Epoch 3/200
# 57/57 [==============================] - 0s 1ms/step - loss: 2.2220 - accuracy: 0.1241
# Epoch 4/200
# 57/57 [==============================] - 0s 1ms/step - loss: 2.2011 - accuracy: 0.1064
# Epoch 5/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.1531 - accuracy: 0.1950
# Epoch 6/200
# 57/57 [==============================] - 0s 1ms/step - loss: 2.1677 - accuracy: 0.1383
# Epoch 7/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.1674 - accuracy: 0.1135
# Epoch 8/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.1642 - accuracy: 0.1773
# Epoch 9/200
# 57/57 [==============================] - 0s 1ms/step - loss: 2.1620 - accuracy: 0.1312
# Epoch 10/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.1420 - accuracy: 0.1986
# Epoch 11/200
# 57/57 [==============================] - 0s 3ms/step - loss: 2.1153 - accuracy: 0.1702
# Epoch 12/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.1212 - accuracy: 0.1773
# Epoch 13/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.0853 - accuracy: 0.2234
# Epoch 14/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.1195 - accuracy: 0.1702
# Epoch 15/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.0586 - accuracy: 0.2163
# Epoch 16/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.0679 - accuracy: 0.2128
# Epoch 17/200
# 57/57 [==============================] - 0s 3ms/step - loss: 2.0698 - accuracy: 0.1915
# Epoch 18/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.0494 - accuracy: 0.2518
# Epoch 19/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.0408 - accuracy: 0.2482
# Epoch 20/200
# 57/57 [==============================] - 0s 2ms/step - loss: 2.0032 - accuracy: 0.2589
# Epoch 21/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.9921 - accuracy: 0.2908
# Epoch 22/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.9897 - accuracy: 0.2624
# Epoch 23/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.9687 - accuracy: 0.2447
# Epoch 24/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.9694 - accuracy: 0.2624
# Epoch 25/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.9230 - accuracy: 0.2979
# Epoch 26/200
# 57/57 [==============================] - 0s 3ms/step - loss: 1.9715 - accuracy: 0.2766
# Epoch 27/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.9144 - accuracy: 0.3014
# Epoch 28/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.9027 - accuracy: 0.2660
# Epoch 29/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.8970 - accuracy: 0.3085
# Epoch 30/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.8686 - accuracy: 0.2943
# Epoch 31/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.8613 - accuracy: 0.2908
# Epoch 32/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.8106 - accuracy: 0.3404
# Epoch 33/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.7796 - accuracy: 0.3617
# Epoch 34/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.7907 - accuracy: 0.3156
# Epoch 35/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.8128 - accuracy: 0.3369
# Epoch 36/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.7545 - accuracy: 0.3546
# Epoch 37/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.7374 - accuracy: 0.3475
# Epoch 38/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.7484 - accuracy: 0.3723
# Epoch 39/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.7170 - accuracy: 0.3723
# Epoch 40/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.6867 - accuracy: 0.3794
# Epoch 41/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.6772 - accuracy: 0.4433
# Epoch 42/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.6168 - accuracy: 0.4681
# Epoch 43/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.6821 - accuracy: 0.4043
# Epoch 44/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.5549 - accuracy: 0.4610
# Epoch 45/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.6142 - accuracy: 0.4539
# Epoch 46/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.6247 - accuracy: 0.4007
# Epoch 47/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.6006 - accuracy: 0.4149
# Epoch 48/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.5754 - accuracy: 0.4255
# Epoch 49/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.5256 - accuracy: 0.4716
# Epoch 50/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.5334 - accuracy: 0.4397
# Epoch 51/200
# 57/57 [==============================] - 0s 3ms/step - loss: 1.5357 - accuracy: 0.4255
# Epoch 52/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.4990 - accuracy: 0.5106
# Epoch 53/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.4448 - accuracy: 0.5071
# Epoch 54/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.4088 - accuracy: 0.5248
# Epoch 55/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.4445 - accuracy: 0.4894
# Epoch 56/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.4200 - accuracy: 0.5071
# Epoch 57/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.3937 - accuracy: 0.5319
# Epoch 58/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.3610 - accuracy: 0.5355
# Epoch 59/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.3958 - accuracy: 0.5035
# Epoch 60/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.2905 - accuracy: 0.5567
# Epoch 61/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.2787 - accuracy: 0.6099
# Epoch 62/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.3554 - accuracy: 0.5390
# Epoch 63/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.3196 - accuracy: 0.5461
# Epoch 64/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.2491 - accuracy: 0.5780
# Epoch 65/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.2767 - accuracy: 0.6028
# Epoch 66/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.2377 - accuracy: 0.5567
# Epoch 67/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.2247 - accuracy: 0.5957
# Epoch 68/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.1895 - accuracy: 0.6135
# Epoch 69/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.2259 - accuracy: 0.5993
# Epoch 70/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.1713 - accuracy: 0.5993
# Epoch 71/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.1791 - accuracy: 0.6206
# Epoch 72/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.1617 - accuracy: 0.6525
# Epoch 73/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.1356 - accuracy: 0.6277
# Epoch 74/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.1361 - accuracy: 0.6525
# Epoch 75/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.1551 - accuracy: 0.6028
# Epoch 76/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.1645 - accuracy: 0.6170
# Epoch 77/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.1146 - accuracy: 0.6383
# Epoch 78/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.1675 - accuracy: 0.5993
# Epoch 79/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.0706 - accuracy: 0.6560
# Epoch 80/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.0273 - accuracy: 0.6631
# Epoch 81/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.0270 - accuracy: 0.6950
# Epoch 82/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.0424 - accuracy: 0.6738
# Epoch 83/200
# 57/57 [==============================] - 0s 2ms/step - loss: 1.0991 - accuracy: 0.6312
# Epoch 84/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.0192 - accuracy: 0.6773
# Epoch 85/200
# 57/57 [==============================] - 0s 1ms/step - loss: 1.0093 - accuracy: 0.6596
# Epoch 86/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.9475 - accuracy: 0.7021
# Epoch 87/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.9568 - accuracy: 0.6986
# Epoch 88/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.9539 - accuracy: 0.7057
# Epoch 89/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.9046 - accuracy: 0.7234
# Epoch 90/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8960 - accuracy: 0.7270
# Epoch 91/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.9418 - accuracy: 0.6879
# Epoch 92/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8473 - accuracy: 0.7447
# Epoch 93/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8976 - accuracy: 0.6879
# Epoch 94/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.9316 - accuracy: 0.7411
# Epoch 95/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8088 - accuracy: 0.7518
# Epoch 96/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8781 - accuracy: 0.7092
# Epoch 97/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8160 - accuracy: 0.7482
# Epoch 98/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8762 - accuracy: 0.7234
# Epoch 99/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7927 - accuracy: 0.7624
# Epoch 100/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8394 - accuracy: 0.7305
# Epoch 101/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8126 - accuracy: 0.7553
# Epoch 102/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6984 - accuracy: 0.8582
# Epoch 103/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8323 - accuracy: 0.7340
# Epoch 104/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8460 - accuracy: 0.7589
# Epoch 105/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.8347 - accuracy: 0.7128
# Epoch 106/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7255 - accuracy: 0.8050
# Epoch 107/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.7687 - accuracy: 0.7695
# Epoch 108/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7294 - accuracy: 0.7908
# Epoch 109/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7584 - accuracy: 0.7801
# Epoch 110/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.8014
# Epoch 111/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7505 - accuracy: 0.7837
# Epoch 112/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6770 - accuracy: 0.7908
# Epoch 113/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6503 - accuracy: 0.8156
# Epoch 114/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.7216 - accuracy: 0.7872
# Epoch 115/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5876 - accuracy: 0.8475
# Epoch 116/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.7178 - accuracy: 0.7695
# Epoch 117/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6648 - accuracy: 0.7837
# Epoch 118/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6410 - accuracy: 0.7943
# Epoch 119/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6086 - accuracy: 0.8227
# Epoch 120/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6187 - accuracy: 0.8191
# Epoch 121/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6547 - accuracy: 0.7908
# Epoch 122/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5537 - accuracy: 0.8582
# Epoch 123/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.8475
# Epoch 124/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5576 - accuracy: 0.8262
# Epoch 125/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.7908
# Epoch 126/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5134 - accuracy: 0.8475
# Epoch 127/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.8369
# Epoch 128/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.8475
# Epoch 129/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5659 - accuracy: 0.8333
# Epoch 130/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5574 - accuracy: 0.8227
# Epoch 131/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5825 - accuracy: 0.8156
# Epoch 132/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5193 - accuracy: 0.8511
# Epoch 133/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5851 - accuracy: 0.8333
# Epoch 134/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4696 - accuracy: 0.8546
# Epoch 135/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5549 - accuracy: 0.8191
# Epoch 136/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.8475
# Epoch 137/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.9113
# Epoch 138/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5067 - accuracy: 0.8404
# Epoch 139/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5369 - accuracy: 0.8404
# Epoch 140/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4966 - accuracy: 0.8652
# Epoch 141/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.8652
# Epoch 142/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5019 - accuracy: 0.8546
# Epoch 143/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4547 - accuracy: 0.8794
# Epoch 144/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.8333
# Epoch 145/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.5053 - accuracy: 0.8511
# Epoch 146/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4648 - accuracy: 0.8652
# Epoch 147/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5240 - accuracy: 0.8582
# Epoch 148/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8972
# Epoch 149/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5229 - accuracy: 0.8404
# Epoch 150/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.8865
# Epoch 151/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4015 - accuracy: 0.8972
# Epoch 152/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3527 - accuracy: 0.9149
# Epoch 153/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.8688
# Epoch 154/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4144 - accuracy: 0.8652
# Epoch 155/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.8972
# Epoch 156/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.9078
# Epoch 157/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.8830
# Epoch 158/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.8901
# Epoch 159/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8901
# Epoch 160/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8865
# Epoch 161/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3747 - accuracy: 0.8652
# Epoch 162/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8759
# Epoch 163/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.9043
# Epoch 164/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8972
# Epoch 165/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3462 - accuracy: 0.9007
# Epoch 166/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3639 - accuracy: 0.9291
# Epoch 167/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3827 - accuracy: 0.8865
# Epoch 168/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3485 - accuracy: 0.9007
# Epoch 169/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8759
# Epoch 170/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3445 - accuracy: 0.9078
# Epoch 171/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3342 - accuracy: 0.8936
# Epoch 172/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3664 - accuracy: 0.8936
# Epoch 173/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.8972
# Epoch 174/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3111 - accuracy: 0.9078
# Epoch 175/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3147 - accuracy: 0.9362
# Epoch 176/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3138 - accuracy: 0.9007
# Epoch 177/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3413 - accuracy: 0.9184
# Epoch 178/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2812 - accuracy: 0.9291
# Epoch 179/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3737 - accuracy: 0.9043
# Epoch 180/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3154 - accuracy: 0.9113
# Epoch 181/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3116 - accuracy: 0.9255
# Epoch 182/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3255 - accuracy: 0.8936
# Epoch 183/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2945 - accuracy: 0.9113
# Epoch 184/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3146 - accuracy: 0.9149
# Epoch 185/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2731 - accuracy: 0.9326
# Epoch 186/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2509 - accuracy: 0.9291
# Epoch 187/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2510 - accuracy: 0.9326
# Epoch 188/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3341 - accuracy: 0.9078
# Epoch 189/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2549 - accuracy: 0.9184
# Epoch 190/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2644 - accuracy: 0.9291
# Epoch 191/200
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3260 - accuracy: 0.9078
# Epoch 192/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8901
# Epoch 193/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2940 - accuracy: 0.9149
# Epoch 194/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3314 - accuracy: 0.9007
# Epoch 195/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2880 - accuracy: 0.9184
# Epoch 196/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3015 - accuracy: 0.9078
# Epoch 197/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2788 - accuracy: 0.9007
# Epoch 198/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2795 - accuracy: 0.9007
# Epoch 199/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2651 - accuracy: 0.9220
# Epoch 200/200
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.9220
# The Model Has Been Trained

# %%
# Let's plot the loss over the 10 epochs
fig, axes = plt.subplots(1, 2, figsize=(10,6))

# Let's see how the accuracy fared
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], marker='.', label='Model Accuracy')
plt.title('Training Model Accuracy')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

# Let's see how the Loss developed over the epochs
plt.subplot(1,2,2)
plt.plot(history.history['loss'], marker='.', label='Model Loss', color='orange')
plt.title('Training Loss Accuracy')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()
